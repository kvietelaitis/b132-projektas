# %% [markdown]
# # F1 Strategy: GRU Multi-Task Model + Strategy Simulator
#
# This notebook combines:
# - GRU + MLP multi-task model (stops cls, tire cls, time reg)
# - Strategy enumeration/simulation (0..3 stops)
# - Ranked output with total predicted race time and stint breakdown
# - Train/validation plots for loss and accuracy

# %%
import re
from pathlib import Path
from itertools import product

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
DATA_DIR = Path("openf1_data")
assert DATA_DIR.exists(), f"Missing: {DATA_DIR.resolve()}"

MODEL_FILE = "multitask_strategy_model.keras"
PREPROC_FILE = "multitask_preprocessing.joblib"

RACE_CONTEXT_FILE = "race_context_input.csv"
FORECAST_FILE = "forecast_weather.csv"

WEATHER_FEATURES = ["air_temperature", "track_temperature", "humidity", "rainfall", "wind_speed"]
VALID_COMPOUNDS = ["SOFT", "MEDIUM", "HARD", "INTERMEDIATE", "WET"]
DRY_COMPOUNDS = ["SOFT", "MEDIUM", "HARD"]
DEFAULT_PIT_LOSS = 22.0

# %%
def parse_session_key(path: Path):
    m = re.search(r"_session_(\d+)\.csv$", path.name)
    return int(m.group(1)) if m else None

def safe_read_csv(path: Path):
    try:
        return pd.read_csv(path)
    except Exception:
        return pd.DataFrame()

def safe_mode(series, default="MEDIUM"):
    s = pd.Series(series).dropna()
    if s.empty:
        return default
    m = s.mode()
    return m.iloc[0] if not m.empty else default

def format_time(sec):
    m = int(sec // 60)
    s = sec - m * 60
    return f"{m}:{s:06.3f}"

# %%
def load_session_maps():
    sessions = safe_read_csv(DATA_DIR / "sessions.csv")
    if sessions.empty:
        return {}, {}, {}

    for c in ["session_key", "meeting_key", "session_name", "location", "circuit_short_name"]:
        if c not in sessions.columns:
            sessions[c] = np.nan

    sessions["track_name"] = sessions["circuit_short_name"].fillna(sessions["location"]).fillna(sessions["meeting_key"].astype(str))
    return (
        dict(zip(sessions["session_key"], sessions["track_name"])),
        dict(zip(sessions["session_key"], sessions["meeting_key"])),
        dict(zip(sessions["session_key"], sessions["session_name"].astype(str))),
    )

session_to_track, session_to_meeting, session_to_name = load_session_maps()

# %% [markdown]
# ## Build training data for GRU multi-task

# %%
def get_weather_seq_and_summary(session_key):
    w = safe_read_csv(DATA_DIR / f"weather_session_{session_key}.csv")
    if w.empty:
        return None, None

    for c in WEATHER_FEATURES:
        if c not in w.columns:
            w[c] = np.nan
        w[c] = pd.to_numeric(w[c], errors="coerce")

    w = w.dropna(subset=WEATHER_FEATURES, how="all")
    if w.empty:
        return None, None

    seq = w[WEATHER_FEATURES].ffill().bfill().fillna(0.0).values
    summary = {
        "air_temp_mean": float(w["air_temperature"].mean()),
        "track_temp_mean": float(w["track_temperature"].mean()),
        "humidity_mean": float(w["humidity"].mean()),
        "rain_minutes_ratio": float((w["rainfall"].fillna(0) > 0).mean()),
        "wind_speed_mean": float(w["wind_speed"].mean()),
    }
    return seq, summary

def estimate_time_loss_target(session_key, team_name, driver_team):
    p = safe_read_csv(DATA_DIR / f"pit_session_{session_key}.csv")
    if p.empty or "driver_number" not in p.columns:
        return 0.0
    p = p.merge(driver_team, on="driver_number", how="left")
    p = p[p["team_name"] == team_name]
    if p.empty:
        return 0.0
    # If no duration, nominal
    for c in ["pit_duration", "duration", "pit_time"]:
        if c in p.columns:
            d = pd.to_numeric(p[c], errors="coerce").dropna()
            if len(d):
                return float(d.sum() + 15.0 * len(d))
    return float(21.0 * len(p))

def build_samples(race_only=True):
    rows, seqs = [], []
    for sf in sorted(DATA_DIR.glob("stints_session_*.csv")):
        sid = parse_session_key(sf)
        if sid is None:
            continue
        sname = session_to_name.get(sid, "")
        if race_only and ("Race" not in sname and "RACE" not in sname):
            continue

        st = safe_read_csv(sf)
        dr = safe_read_csv(DATA_DIR / f"drivers_session_{sid}.csv")
        if st.empty or dr.empty:
            continue

        for c in ["driver_number", "compound", "stint_number"]:
            if c not in st.columns:
                st[c] = np.nan
        for c in ["driver_number", "team_name"]:
            if c not in dr.columns:
                dr[c] = np.nan

        driver_team = dr[["driver_number", "team_name"]].dropna().drop_duplicates()
        st = st.merge(driver_team, on="driver_number", how="left")

        pits = safe_read_csv(DATA_DIR / f"pit_session_{sid}.csv")
        if pits.empty:
            pits = pd.DataFrame(columns=["driver_number"])
        if "driver_number" not in pits.columns:
            pits["driver_number"] = np.nan
        pits = pits.merge(driver_team, on="driver_number", how="left")

        grid = safe_read_csv(DATA_DIR / f"starting_grid_session_{sid}.csv")
        pos_col = "position" if "position" in grid.columns else ("grid_position" if "grid_position" in grid.columns else None)
        if not grid.empty and pos_col and "driver_number" in grid.columns:
            g = grid[["driver_number", pos_col]].copy()
            g.columns = ["driver_number", "starting_position"]
            g["starting_position"] = pd.to_numeric(g["starting_position"], errors="coerce")
            g = g.merge(driver_team, on="driver_number", how="left")
            team_pos = g.groupby("team_name")["starting_position"].mean().to_dict()
        else:
            team_pos = {}

        seq, ws = get_weather_seq_and_summary(sid)
        if seq is None:
            continue

        track = str(session_to_track.get(sid, session_to_meeting.get(sid, "UNKNOWN_TRACK")))

        for team, t_st in st.groupby("team_name", dropna=True):
            team = str(team)
            t_pits = pits[pits["team_name"] == team]
            pit_stops = int(len(t_pits))

            s1 = t_st[t_st["stint_number"] == 1]
            start_comp = safe_mode(s1["compound"] if len(s1) else t_st["compound"], default="MEDIUM")
            start_comp = str(start_comp).upper()
            if start_comp not in VALID_COMPOUNDS:
                start_comp = "MEDIUM"

            non_start = t_st[t_st["compound"].astype(str).str.upper() != start_comp]["compound"]
            target_comp = str(safe_mode(non_start, default=safe_mode(t_st["compound"], "MEDIUM"))).upper()
            if target_comp not in VALID_COMPOUNDS:
                target_comp = "MEDIUM"

            rows.append({
                "session_key": sid,
                "team_name": team,
                "track_name": track,
                "starting_position": float(team_pos.get(team, 10.0)),
                "starting_compound": start_comp,
                "pit_stops": pit_stops,
                "target_compound": target_comp,
                "time_loss_target": estimate_time_loss_target(sid, team, driver_team),
                **ws,
            })
            seqs.append(seq)
    return pd.DataFrame(rows), seqs

df, X_seq_raw = build_samples(race_only=True)
print(len(df))
df.head()
# Out:
# 90
#    session_key     team_name track_name  starting_position starting_compound  \
# 0        10033        Alpine      Miami               10.0              HARD
# 1        10033  Aston Martin      Miami               10.0              HARD
# 2        10033       Ferrari      Miami               10.0              HARD
# 3        10033  Haas F1 Team      Miami               10.0              HARD
# 4        10033   Kick Sauber      Miami               10.0              HARD
#
#    pit_stops target_compound  time_loss_target  air_temp_mean  \
# 0          1          MEDIUM            37.060      26.573154
# 1          2          MEDIUM            75.919      26.573154
# 2          2          MEDIUM            75.287      26.573154
# 3          1          MEDIUM            38.162      26.573154
# 4          2          MEDIUM            74.296      26.573154
#
#    track_temp_mean  humidity_mean  rain_minutes_ratio  wind_speed_mean
# 0        38.690604      63.020134            0.033557          1.04698
# 1        38.690604      63.020134            0.033557          1.04698
# 2        38.690604      63.020134            0.033557          1.04698
# 3        38.690604      63.020134            0.033557          1.04698
# 4        38.690604      63.020134            0.033557          1.04698

# %%
team_le = LabelEncoder(); track_le = LabelEncoder(); start_le = LabelEncoder()
stops_le = LabelEncoder(); tire_le = LabelEncoder()

df["team_id"] = team_le.fit_transform(df["team_name"].astype(str))
df["track_id"] = track_le.fit_transform(df["track_name"].astype(str))
df["start_id"] = start_le.fit_transform(df["starting_compound"].astype(str))

y_stops = stops_le.fit_transform(df["pit_stops"])
y_tire = tire_le.fit_transform(df["target_compound"].astype(str))
y_time_raw = df["time_loss_target"].astype(float).values
y_time_mean = y_time_raw.mean()
y_time_std = y_time_raw.std() + 1e-8
y_time = ((y_time_raw - y_time_mean) / y_time_std).astype("float32")

NUM_COLS = ["starting_position", "air_temp_mean", "track_temp_mean", "humidity_mean", "rain_minutes_ratio", "wind_speed_mean"]
for c in NUM_COLS:
    df[c] = pd.to_numeric(df[c], errors="coerce")
    df[c] = df[c].fillna(df[c].median())

X_num = df[NUM_COLS].values.astype("float32")
X_team = df["team_id"].values.astype("int32")
X_track = df["track_id"].values.astype("int32")
X_start = df["start_id"].values.astype("int32")
X_seq = pad_sequences(X_seq_raw, padding="post", dtype="float32")

idx = np.arange(len(df))
tr_idx, va_idx = train_test_split(idx, test_size=0.2, random_state=42)

X_train = {
    "weather_seq": X_seq[tr_idx],
    "team_in": X_team[tr_idx],
    "track_in": X_track[tr_idx],
    "start_comp_in": X_start[tr_idx],
    "num_in": X_num[tr_idx],
}
X_val = {
    "weather_seq": X_seq[va_idx],
    "team_in": X_team[va_idx],
    "track_in": X_track[va_idx],
    "start_comp_in": X_start[va_idx],
    "num_in": X_num[va_idx],
}
y_train = {"stops_head": y_stops[tr_idx], "tire_head": y_tire[tr_idx], "time_head": y_time[tr_idx]}
y_val = {"stops_head": y_stops[va_idx], "tire_head": y_tire[va_idx], "time_head": y_time[va_idx]}

# %% [markdown]
# ## Build and train GRU multi-task model

# %%
T, F = X_seq.shape[1], X_seq.shape[2]
n_team, n_track, n_start = len(team_le.classes_), len(track_le.classes_), len(start_le.classes_)
n_stops, n_tire = len(stops_le.classes_), len(tire_le.classes_)

weather_in = keras.Input(shape=(T, F), name="weather_seq")
team_in = keras.Input(shape=(1,), dtype="int32", name="team_in")
track_in = keras.Input(shape=(1,), dtype="int32", name="track_in")
start_in = keras.Input(shape=(1,), dtype="int32", name="start_comp_in")
num_in = keras.Input(shape=(len(NUM_COLS),), dtype="float32", name="num_in")

w = layers.GRU(64, name="weather_gru")(weather_in)
te = layers.Reshape((-1,))(layers.Embedding(n_team, min(16, max(4, n_team // 2)))(team_in))
tr = layers.Reshape((-1,))(layers.Embedding(n_track, min(16, max(4, n_track // 2)))(track_in))
sc = layers.Reshape((-1,))(layers.Embedding(n_start, min(8, max(3, n_start // 2)))(start_in))

x = layers.Concatenate()([w, te, tr, sc, num_in])
x = layers.Dense(128, activation="relu")(x)
x = layers.Dropout(0.25)(x)
x = layers.Dense(64, activation="relu")(x)

stops_out = layers.Dense(n_stops, activation="softmax", name="stops_head")(x)
tire_out = layers.Dense(n_tire, activation="softmax", name="tire_head")(x)
time_out = layers.Dense(1, activation="linear", name="time_head")(x)

model = keras.Model([weather_in, team_in, track_in, start_in, num_in], [stops_out, tire_out, time_out])
model.compile(
    optimizer="adam",
    loss={"stops_head": "sparse_categorical_crossentropy", "tire_head": "sparse_categorical_crossentropy", "time_head": "mse"},
    loss_weights={"stops_head": 1.0, "tire_head": 1.0, "time_head": 0.1},
    metrics={"stops_head": ["accuracy"], "tire_head": ["accuracy"], "time_head": ["mae"]},
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=40,
    batch_size=32,
    callbacks = [
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=4, min_lr=1e-5),
    ],
    verbose=1,
)
# Out:
# 2026-04-27 12:46:52.760158: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2026-04-27 12:46:52.760198: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-04-27 12:46:52.760216: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-04-27 12:46:52.760232: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-04-27 12:46:52.760243: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/40
# 2026-04-27 12:46:53.600036: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 396ms/step - loss: 66.2831 - stops_head_accuracy: 0.1111 - stops_head_loss: 25.1434 - time_head_loss: 156.3032 - time_head_mae: 12.1237 - tire_head_accuracy: 0.3333 - tire_head_loss: 19.1276 - val_loss: 42.6142 - val_stops_head_accuracy: 0.0000e+00 - val_stops_head_loss: 23.7679 - val_time_head_loss: 25.4175 - val_time_head_mae: 4.7678 - val_tire_head_accuracy: 0.4444 - val_tire_head_loss: 16.3045 - learning_rate: 0.0010
# Epoch 2/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 47.8275 - stops_head_accuracy: 0.1111 - stops_head_loss: 18.1402 - time_head_loss: 117.5279 - time_head_mae: 8.4430 - tire_head_accuracy: 0.3194 - tire_head_loss: 16.4865 - val_loss: 38.3821 - val_stops_head_accuracy: 0.1111 - val_stops_head_loss: 18.7211 - val_time_head_loss: 86.6483 - val_time_head_mae: 9.1405 - val_tire_head_accuracy: 0.4444 - val_tire_head_loss: 10.9962 - learning_rate: 0.0010
# Epoch 3/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 44.0269 - stops_head_accuracy: 0.1806 - stops_head_loss: 19.2888 - time_head_loss: 139.1055 - time_head_mae: 9.2457 - tire_head_accuracy: 0.2917 - tire_head_loss: 12.2600 - val_loss: 26.7640 - val_stops_head_accuracy: 0.1667 - val_stops_head_loss: 16.8720 - val_time_head_loss: 31.7968 - val_time_head_mae: 5.4295 - val_tire_head_accuracy: 0.2778 - val_tire_head_loss: 6.7123 - learning_rate: 0.0010
# Epoch 4/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 34.9363 - stops_head_accuracy: 0.1389 - stops_head_loss: 17.7045 - time_head_loss: 63.9670 - time_head_mae: 6.8260 - tire_head_accuracy: 0.2639 - tire_head_loss: 8.3002 - val_loss: 18.2062 - val_stops_head_accuracy: 0.1667 - val_stops_head_loss: 14.4242 - val_time_head_loss: 2.1877 - val_time_head_mae: 1.3963 - val_tire_head_accuracy: 0.2778 - val_tire_head_loss: 3.5632 - learning_rate: 0.0010
# Epoch 5/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 24.3182 - stops_head_accuracy: 0.1667 - stops_head_loss: 15.0845 - time_head_loss: 34.6592 - time_head_mae: 4.3613 - tire_head_accuracy: 0.2500 - tire_head_loss: 6.6138 - val_loss: 14.6266 - val_stops_head_accuracy: 0.2222 - val_stops_head_loss: 11.9937 - val_time_head_loss: 13.8208 - val_time_head_mae: 3.3933 - val_tire_head_accuracy: 0.4444 - val_tire_head_loss: 1.2508 - learning_rate: 0.0010
# Epoch 6/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 24.7497 - stops_head_accuracy: 0.1944 - stops_head_loss: 12.4917 - time_head_loss: 40.5867 - time_head_mae: 4.9025 - tire_head_accuracy: 0.2083 - tire_head_loss: 5.8414 - val_loss: 12.3147 - val_stops_head_accuracy: 0.1667 - val_stops_head_loss: 8.8670 - val_time_head_loss: 12.2287 - val_time_head_mae: 3.1531 - val_tire_head_accuracy: 0.3889 - val_tire_head_loss: 2.2248 - learning_rate: 0.0010
# Epoch 7/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 23.0362 - stops_head_accuracy: 0.1528 - stops_head_loss: 10.8294 - time_head_loss: 55.6222 - time_head_mae: 6.2383 - tire_head_accuracy: 0.2778 - tire_head_loss: 7.5591 - val_loss: 7.6922 - val_stops_head_accuracy: 0.2222 - val_stops_head_loss: 5.0205 - val_time_head_loss: 2.5062 - val_time_head_mae: 1.5260 - val_tire_head_accuracy: 0.3889 - val_tire_head_loss: 2.4211 - learning_rate: 0.0010
# Epoch 8/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 20.8097 - stops_head_accuracy: 0.1806 - stops_head_loss: 8.3893 - time_head_loss: 48.0010 - time_head_mae: 5.5608 - tire_head_accuracy: 0.3750 - tire_head_loss: 5.3566 - val_loss: 5.8578 - val_stops_head_accuracy: 0.3889 - val_stops_head_loss: 3.5478 - val_time_head_loss: 4.2514 - val_time_head_mae: 1.5906 - val_tire_head_accuracy: 0.3889 - val_tire_head_loss: 1.8849 - learning_rate: 0.0010
# Epoch 9/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 17.7243 - stops_head_accuracy: 0.2222 - stops_head_loss: 8.7594 - time_head_loss: 44.6754 - time_head_mae: 4.8102 - tire_head_accuracy: 0.4028 - tire_head_loss: 5.4725 - val_loss: 8.0970 - val_stops_head_accuracy: 0.3889 - val_stops_head_loss: 5.6236 - val_time_head_loss: 12.2069 - val_time_head_mae: 3.2482 - val_tire_head_accuracy: 0.4444 - val_tire_head_loss: 1.2527 - learning_rate: 0.0010
# Epoch 10/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 19.0564 - stops_head_accuracy: 0.2778 - stops_head_loss: 6.3246 - time_head_loss: 49.5179 - time_head_mae: 5.9193 - tire_head_accuracy: 0.2639 - tire_head_loss: 7.6638 - val_loss: 8.7219 - val_stops_head_accuracy: 0.3889 - val_stops_head_loss: 6.8644 - val_time_head_loss: 7.1030 - val_time_head_mae: 2.3717 - val_tire_head_accuracy: 0.5556 - val_tire_head_loss: 1.1473 - learning_rate: 0.0010
# Epoch 11/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 18.5573 - stops_head_accuracy: 0.2917 - stops_head_loss: 9.0808 - time_head_loss: 36.1121 - time_head_mae: 4.8559 - tire_head_accuracy: 0.3333 - tire_head_loss: 4.5324 - val_loss: 8.5369 - val_stops_head_accuracy: 0.3889 - val_stops_head_loss: 7.0680 - val_time_head_loss: 1.4763 - val_time_head_mae: 0.8987 - val_tire_head_accuracy: 0.5000 - val_tire_head_loss: 1.3213 - learning_rate: 0.0010
# Epoch 12/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 15.6059 - stops_head_accuracy: 0.2917 - stops_head_loss: 8.0587 - time_head_loss: 28.4660 - time_head_mae: 4.4790 - tire_head_accuracy: 0.5278 - tire_head_loss: 3.6991 - val_loss: 7.7537 - val_stops_head_accuracy: 0.3889 - val_stops_head_loss: 6.1330 - val_time_head_loss: 2.3848 - val_time_head_mae: 1.4497 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 1.3822 - learning_rate: 0.0010
# Epoch 13/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 17.1991 - stops_head_accuracy: 0.2361 - stops_head_loss: 9.1871 - time_head_loss: 29.2803 - time_head_mae: 4.2746 - tire_head_accuracy: 0.4167 - tire_head_loss: 4.5833 - val_loss: 7.2055 - val_stops_head_accuracy: 0.3889 - val_stops_head_loss: 5.5098 - val_time_head_loss: 2.6564 - val_time_head_mae: 1.4991 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 1.4301 - learning_rate: 5.0000e-04
# Epoch 14/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 17.6955 - stops_head_accuracy: 0.2500 - stops_head_loss: 7.9365 - time_head_loss: 23.9181 - time_head_mae: 4.1380 - tire_head_accuracy: 0.3194 - tire_head_loss: 4.9801 - val_loss: 6.4795 - val_stops_head_accuracy: 0.3889 - val_stops_head_loss: 4.8729 - val_time_head_loss: 1.6306 - val_time_head_mae: 1.2277 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 1.4436 - learning_rate: 5.0000e-04
# Epoch 15/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 16.3959 - stops_head_accuracy: 0.2639 - stops_head_loss: 6.7759 - time_head_loss: 37.7151 - time_head_mae: 5.0012 - tire_head_accuracy: 0.3194 - tire_head_loss: 4.9045 - val_loss: 6.0454 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 4.5012 - val_time_head_loss: 1.1291 - val_time_head_mae: 0.8489 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 1.4313 - learning_rate: 5.0000e-04
# Epoch 16/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 15.4525 - stops_head_accuracy: 0.2500 - stops_head_loss: 6.7988 - time_head_loss: 39.2284 - time_head_mae: 4.2411 - tire_head_accuracy: 0.2917 - tire_head_loss: 6.0210 - val_loss: 5.7882 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 4.2566 - val_time_head_loss: 1.5521 - val_time_head_mae: 0.7856 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 1.3764 - learning_rate: 5.0000e-04
# Epoch 17/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 14.8459 - stops_head_accuracy: 0.3611 - stops_head_loss: 6.5925 - time_head_loss: 32.3697 - time_head_mae: 4.7075 - tire_head_accuracy: 0.4306 - tire_head_loss: 4.9512 - val_loss: 5.5620 - val_stops_head_accuracy: 0.3333 - val_stops_head_loss: 4.0172 - val_time_head_loss: 1.6242 - val_time_head_mae: 0.7960 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 1.3824 - learning_rate: 5.0000e-04
# Epoch 18/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 13.8775 - stops_head_accuracy: 0.2917 - stops_head_loss: 6.3118 - time_head_loss: 25.5219 - time_head_mae: 4.0455 - tire_head_accuracy: 0.4306 - tire_head_loss: 5.5831 - val_loss: 5.1231 - val_stops_head_accuracy: 0.3333 - val_stops_head_loss: 3.7320 - val_time_head_loss: 1.3030 - val_time_head_mae: 0.7151 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 1.2608 - learning_rate: 5.0000e-04
# Epoch 19/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 15.0207 - stops_head_accuracy: 0.2361 - stops_head_loss: 5.7995 - time_head_loss: 38.5549 - time_head_mae: 4.6731 - tire_head_accuracy: 0.4444 - tire_head_loss: 3.9060 - val_loss: 4.5964 - val_stops_head_accuracy: 0.3333 - val_stops_head_loss: 3.3872 - val_time_head_loss: 1.0129 - val_time_head_mae: 0.6884 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 1.1079 - learning_rate: 5.0000e-04
# Epoch 20/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 14.1994 - stops_head_accuracy: 0.3194 - stops_head_loss: 6.6562 - time_head_loss: 20.1908 - time_head_mae: 3.8855 - tire_head_accuracy: 0.3472 - tire_head_loss: 5.7390 - val_loss: 4.2693 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 3.1762 - val_time_head_loss: 0.8989 - val_time_head_mae: 0.7640 - val_tire_head_accuracy: 0.5000 - val_tire_head_loss: 1.0032 - learning_rate: 5.0000e-04
# Epoch 21/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 13.2479 - stops_head_accuracy: 0.3750 - stops_head_loss: 6.3237 - time_head_loss: 25.3113 - time_head_mae: 3.6727 - tire_head_accuracy: 0.4583 - tire_head_loss: 5.0202 - val_loss: 4.1343 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 3.1046 - val_time_head_loss: 1.1340 - val_time_head_mae: 0.9898 - val_tire_head_accuracy: 0.5556 - val_tire_head_loss: 0.9163 - learning_rate: 5.0000e-04
# Epoch 22/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 14.5551 - stops_head_accuracy: 0.2639 - stops_head_loss: 5.7942 - time_head_loss: 37.7905 - time_head_mae: 4.0362 - tire_head_accuracy: 0.2639 - tire_head_loss: 5.9901 - val_loss: 4.1290 - val_stops_head_accuracy: 0.3333 - val_stops_head_loss: 3.0714 - val_time_head_loss: 1.3768 - val_time_head_mae: 1.0744 - val_tire_head_accuracy: 0.6667 - val_tire_head_loss: 0.9199 - learning_rate: 5.0000e-04
# Epoch 23/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 15.3190 - stops_head_accuracy: 0.1528 - stops_head_loss: 8.1527 - time_head_loss: 34.4468 - time_head_mae: 3.8070 - tire_head_accuracy: 0.3194 - tire_head_loss: 5.0641 - val_loss: 4.2478 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 3.1378 - val_time_head_loss: 1.1329 - val_time_head_mae: 0.9741 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 0.9967 - learning_rate: 5.0000e-04
# Epoch 24/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 15.4197 - stops_head_accuracy: 0.2083 - stops_head_loss: 7.7317 - time_head_loss: 23.8226 - time_head_mae: 4.0447 - tire_head_accuracy: 0.3889 - tire_head_loss: 3.9906 - val_loss: 4.2574 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 3.1319 - val_time_head_loss: 0.8872 - val_time_head_mae: 0.8467 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 1.0367 - learning_rate: 5.0000e-04
# Epoch 25/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 14.9546 - stops_head_accuracy: 0.2083 - stops_head_loss: 7.7054 - time_head_loss: 24.1204 - time_head_mae: 4.1688 - tire_head_accuracy: 0.4167 - tire_head_loss: 4.2579 - val_loss: 4.2358 - val_stops_head_accuracy: 0.3333 - val_stops_head_loss: 3.1027 - val_time_head_loss: 0.7550 - val_time_head_mae: 0.6866 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 1.0576 - learning_rate: 5.0000e-04
# Epoch 26/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 13.5631 - stops_head_accuracy: 0.1806 - stops_head_loss: 5.5926 - time_head_loss: 32.4443 - time_head_mae: 4.3243 - tire_head_accuracy: 0.4861 - tire_head_loss: 4.4264 - val_loss: 4.2182 - val_stops_head_accuracy: 0.3333 - val_stops_head_loss: 3.0690 - val_time_head_loss: 0.8094 - val_time_head_mae: 0.6055 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 1.0682 - learning_rate: 5.0000e-04
# Epoch 27/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 14.4512 - stops_head_accuracy: 0.1806 - stops_head_loss: 7.7929 - time_head_loss: 33.2765 - time_head_mae: 4.3839 - tire_head_accuracy: 0.4583 - tire_head_loss: 4.8873 - val_loss: 4.1950 - val_stops_head_accuracy: 0.3333 - val_stops_head_loss: 3.0525 - val_time_head_loss: 0.8060 - val_time_head_mae: 0.6073 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 1.0619 - learning_rate: 2.5000e-04
# Epoch 28/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 14.4870 - stops_head_accuracy: 0.1389 - stops_head_loss: 7.2815 - time_head_loss: 21.0820 - time_head_mae: 3.8069 - tire_head_accuracy: 0.3750 - tire_head_loss: 4.6333 - val_loss: 4.1249 - val_stops_head_accuracy: 0.3333 - val_stops_head_loss: 3.0057 - val_time_head_loss: 0.7898 - val_time_head_mae: 0.6146 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 1.0402 - learning_rate: 2.5000e-04
# Epoch 29/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 14.3074 - stops_head_accuracy: 0.2778 - stops_head_loss: 5.9279 - time_head_loss: 29.6843 - time_head_mae: 4.5486 - tire_head_accuracy: 0.3472 - tire_head_loss: 5.3499 - val_loss: 4.1009 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 3.0062 - val_time_head_loss: 0.8082 - val_time_head_mae: 0.6016 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 1.0138 - learning_rate: 2.5000e-04
# Epoch 30/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 13.8054 - stops_head_accuracy: 0.2917 - stops_head_loss: 7.2469 - time_head_loss: 21.8149 - time_head_mae: 4.0306 - tire_head_accuracy: 0.4722 - tire_head_loss: 4.6815 - val_loss: 4.0475 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 2.9684 - val_time_head_loss: 0.7885 - val_time_head_mae: 0.6021 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 1.0002 - learning_rate: 2.5000e-04
# Epoch 31/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 14.8523 - stops_head_accuracy: 0.2361 - stops_head_loss: 8.3805 - time_head_loss: 21.0848 - time_head_mae: 3.6287 - tire_head_accuracy: 0.4028 - tire_head_loss: 5.6423 - val_loss: 4.0223 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 2.9283 - val_time_head_loss: 0.7209 - val_time_head_mae: 0.6501 - val_tire_head_accuracy: 0.5000 - val_tire_head_loss: 1.0218 - learning_rate: 2.5000e-04
# Epoch 32/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 14.1784 - stops_head_accuracy: 0.2361 - stops_head_loss: 6.4512 - time_head_loss: 33.3315 - time_head_mae: 4.4315 - tire_head_accuracy: 0.3333 - tire_head_loss: 3.6283 - val_loss: 3.9753 - val_stops_head_accuracy: 0.2222 - val_stops_head_loss: 2.8769 - val_time_head_loss: 0.7269 - val_time_head_mae: 0.7560 - val_tire_head_accuracy: 0.5000 - val_tire_head_loss: 1.0257 - learning_rate: 2.5000e-04
# Epoch 33/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 13.8329 - stops_head_accuracy: 0.1528 - stops_head_loss: 6.6358 - time_head_loss: 24.8083 - time_head_mae: 4.3637 - tire_head_accuracy: 0.3611 - tire_head_loss: 3.8188 - val_loss: 3.9435 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 2.8765 - val_time_head_loss: 0.7177 - val_time_head_mae: 0.7583 - val_tire_head_accuracy: 0.5000 - val_tire_head_loss: 0.9953 - learning_rate: 2.5000e-04
# Epoch 34/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 14.7333 - stops_head_accuracy: 0.2639 - stops_head_loss: 6.1830 - time_head_loss: 21.2605 - time_head_mae: 3.8148 - tire_head_accuracy: 0.3611 - tire_head_loss: 6.0732 - val_loss: 3.9743 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 2.9597 - val_time_head_loss: 0.7187 - val_time_head_mae: 0.7720 - val_tire_head_accuracy: 0.5556 - val_tire_head_loss: 0.9427 - learning_rate: 2.5000e-04
# Epoch 35/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 16.3774 - stops_head_accuracy: 0.2083 - stops_head_loss: 8.0460 - time_head_loss: 27.8423 - time_head_mae: 3.9606 - tire_head_accuracy: 0.3333 - tire_head_loss: 6.3553 - val_loss: 3.9550 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 2.9638 - val_time_head_loss: 0.6977 - val_time_head_mae: 0.7576 - val_tire_head_accuracy: 0.5556 - val_tire_head_loss: 0.9214 - learning_rate: 2.5000e-04
# Epoch 36/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 14.0394 - stops_head_accuracy: 0.1806 - stops_head_loss: 6.6841 - time_head_loss: 22.3648 - time_head_mae: 4.0511 - tire_head_accuracy: 0.4028 - tire_head_loss: 3.5795 - val_loss: 3.9235 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 2.9285 - val_time_head_loss: 0.6447 - val_time_head_mae: 0.6723 - val_tire_head_accuracy: 0.5556 - val_tire_head_loss: 0.9306 - learning_rate: 2.5000e-04
# Epoch 37/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 13.7830 - stops_head_accuracy: 0.2639 - stops_head_loss: 6.5434 - time_head_loss: 21.9304 - time_head_mae: 3.7557 - tire_head_accuracy: 0.4583 - tire_head_loss: 3.9837 - val_loss: 3.9490 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 2.9162 - val_time_head_loss: 0.7053 - val_time_head_mae: 0.5512 - val_tire_head_accuracy: 0.6111 - val_tire_head_loss: 0.9623 - learning_rate: 2.5000e-04
# Epoch 38/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 13.7834 - stops_head_accuracy: 0.3472 - stops_head_loss: 6.5443 - time_head_loss: 29.8850 - time_head_mae: 3.6147 - tire_head_accuracy: 0.3194 - tire_head_loss: 5.2673 - val_loss: 4.0556 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 2.9619 - val_time_head_loss: 1.0530 - val_time_head_mae: 0.6872 - val_tire_head_accuracy: 0.5000 - val_tire_head_loss: 0.9884 - learning_rate: 2.5000e-04
# Epoch 39/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 14.2678 - stops_head_accuracy: 0.2917 - stops_head_loss: 7.3541 - time_head_loss: 19.0719 - time_head_mae: 3.8987 - tire_head_accuracy: 0.4028 - tire_head_loss: 5.8899 - val_loss: 4.1809 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 3.0310 - val_time_head_loss: 1.7537 - val_time_head_mae: 1.1158 - val_tire_head_accuracy: 0.5000 - val_tire_head_loss: 0.9746 - learning_rate: 2.5000e-04
# Epoch 40/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 13.0666 - stops_head_accuracy: 0.2500 - stops_head_loss: 6.3073 - time_head_loss: 21.5861 - time_head_mae: 3.9786 - tire_head_accuracy: 0.4722 - tire_head_loss: 3.2136 - val_loss: 4.2724 - val_stops_head_accuracy: 0.2778 - val_stops_head_loss: 3.0131 - val_time_head_loss: 2.2851 - val_time_head_mae: 1.3481 - val_tire_head_accuracy: 0.5000 - val_tire_head_loss: 1.0308 - learning_rate: 2.5000e-04

# %%
h = history.history
ep = range(1, len(h["loss"]) + 1)

fig, ax = plt.subplots(2, 2, figsize=(13, 9))
ax[0,0].plot(ep, h["loss"], label="train"); ax[0,0].plot(ep, h["val_loss"], label="val"); ax[0,0].set_title("Total Loss"); ax[0,0].legend(); ax[0,0].grid(alpha=.3)
ax[0,1].plot(ep, h["stops_head_accuracy"], label="train"); ax[0,1].plot(ep, h["val_stops_head_accuracy"], label="val"); ax[0,1].set_title("Stops Accuracy"); ax[0,1].legend(); ax[0,1].grid(alpha=.3)
ax[1,0].plot(ep, h["tire_head_accuracy"], label="train"); ax[1,0].plot(ep, h["val_tire_head_accuracy"], label="val"); ax[1,0].set_title("Tire Accuracy"); ax[1,0].legend(); ax[1,0].grid(alpha=.3)
ax[1,1].plot(ep, h["time_head_loss"], label="train"); ax[1,1].plot(ep, h["val_time_head_loss"], label="val"); ax[1,1].set_title("Time Head Loss (MSE)"); ax[1,1].legend(); ax[1,1].grid(alpha=.3)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Save model + preprocessing

# %%
model.save(MODEL_FILE)
joblib.dump({
    "team_le": team_le,
    "track_le": track_le,
    "start_le": start_le,
    "stops_le": stops_le,
    "tire_le": tire_le,
    "num_cols": NUM_COLS,
    "weather_features": WEATHER_FEATURES,
    "max_timesteps": X_seq.shape[1],
    "y_time_mean": float(y_time_mean),
    "y_time_std": float(y_time_std),
}, PREPROC_FILE)
print("Saved", MODEL_FILE, PREPROC_FILE)
# Out:
# Saved multitask_strategy_model.keras multitask_preprocessing.joblib

# %% [markdown]
# ## Strategy simulation using the GRU model (top strategies + consistent stint breakdown)

# %%
def encode_with_unknown(le, val):
    val = str(val)
    if val in set(le.classes_):
        return int(le.transform([val])[0])
    return 0

def estimate_track_pit_loss_map():
    out = {}
    for pf in sorted(DATA_DIR.glob("pit_session_*.csv")):
        sid = parse_session_key(pf)
        if sid is None:
            continue
        track = str(session_to_track.get(sid, "UNKNOWN_TRACK"))
        p = safe_read_csv(pf)
        if p.empty:
            continue
        # no reliable universal duration col; fallback to nominal from count if missing
        dcol = next((c for c in ["pit_duration", "duration", "pit_time"] if c in p.columns), None)
        if dcol:
            d = pd.to_numeric(p[dcol], errors="coerce").dropna()
            if len(d):
                out[track] = float(np.median(d) + 15.0)
    return out

def forecast_to_sequence_and_summary(forecast_df, weather_features, max_timesteps):
    f = forecast_df.copy()
    for c in weather_features:
        if c not in f.columns:
            f[c] = np.nan
        f[c] = pd.to_numeric(f[c], errors="coerce")
    f = f[weather_features].ffill().bfill().fillna(0.0)
    seq = pad_sequences([f.values.astype("float32")], maxlen=max_timesteps, padding="post", dtype="float32")
    summary = {
        "air_temp_mean": float(f["air_temperature"].mean()),
        "track_temp_mean": float(f["track_temperature"].mean()),
        "humidity_mean": float(f["humidity"].mean()),
        "rain_minutes_ratio": float((f["rainfall"] > 0).mean()),
        "wind_speed_mean": float(f["wind_speed"].mean()),
    }
    return seq, summary

def split_laps(total_laps, n_stints):
    b = total_laps // n_stints
    r = total_laps % n_stints
    return [b + (1 if i < r else 0) for i in range(n_stints)]

def build_candidates(start_comp, max_stops=3, wet=False):
    pool = VALID_COMPOUNDS if wet else DRY_COMPOUNDS
    start_comp = str(start_comp).upper()
    if start_comp not in pool:
        start_comp = "MEDIUM" if "MEDIUM" in pool else pool[0]

    cands = []
    for s in range(max_stops + 1):
        if s == 0:
            cands.append([start_comp])
        else:
            for seq in product(pool, repeat=s):
                full = [start_comp] + list(seq)
                if len(set(full)) == 1:  # avoid pointless same compound every stint
                    continue
                cands.append(full)
    return cands

def simulate_with_gru(model, pre, race_context, seq_input, weather_summary, compounds, pit_loss):
    team_id = encode_with_unknown(pre["team_le"], race_context["team_name"])
    track_id = encode_with_unknown(pre["track_le"], race_context["track_name"])
    start_id = encode_with_unknown(pre["start_le"], race_context["starting_compound"])

    num_vec = np.array([[race_context["starting_position"], weather_summary["air_temp_mean"], weather_summary["track_temp_mean"], weather_summary["humidity_mean"], weather_summary["rain_minutes_ratio"], weather_summary["wind_speed_mean"]]], dtype="float32")

    p_stops, p_tire, p_time = model.predict({
        "weather_seq": seq_input,
        "team_in": np.array([team_id], dtype=np.int32),
        "track_in": np.array([track_id], dtype=np.int32),
        "start_comp_in": np.array([start_id], dtype=np.int32),
        "num_in": num_vec,
    }, verbose=0)

    # Base total time estimate from historical pace proxy:
    # approximate avg lap by track temp/rain (simple heuristic baseline)
    total_laps = int(race_context["race_laps"])
    base_lap = 92.0 + 0.08 * max(weather_summary["track_temp_mean"] - 35.0, 0) + 6.0 * weather_summary["rain_minutes_ratio"]
    base_total = base_lap * total_laps

    # Compound delta heuristic per lap (relative)
    comp_delta = {"SOFT": -0.25, "MEDIUM": 0.0, "HARD": 0.18, "INTERMEDIATE": 0.9, "WET": 1.8}
    # Degradation per lap in stint
    degr = {"SOFT": 0.035, "MEDIUM": 0.024, "HARD": 0.018, "INTERMEDIATE": 0.030, "WET": 0.040}

    stint_laps = split_laps(total_laps, len(compounds))
    detailed = []
    sim_time = 0.0
    for i, (c, L) in enumerate(zip(compounds, stint_laps), start=1):
        c = str(c).upper()
        lap_times = []
        for a in range(L):
            lap_t = base_lap + comp_delta.get(c, 0.0) + degr.get(c, 0.025) * a
            lap_times.append(lap_t)
        st_sec = float(np.sum(lap_times))
        sim_time += st_sec
        detailed.append({"stint": i, "compound": c, "laps": L, "predicted_stint_time_sec": st_sec})
        if i < len(compounds):
            sim_time += pit_loss

    # Blend with GRU time-head prediction as calibration term
    gru_time_loss = float(p_time[0][0])
    pred_stops_class = int(np.argmax(p_stops[0]))
    pred_stops_val = int(pre["stops_le"].inverse_transform([pred_stops_class])[0])

    # penalty if candidate stops diverges a lot from model preference
    stop_mismatch_penalty = abs((len(compounds)-1) - pred_stops_val) * 4.0

    total = sim_time + 0.35 * gru_time_loss + stop_mismatch_penalty
    return {
        "strategy": " -> ".join(compounds),
        "stops": len(compounds)-1,
        "predicted_total_time_sec": total,
        "pit_loss_per_stop_sec": pit_loss,
        "gru_predicted_stops": pred_stops_val,
        "gru_tire_class": pre["tire_le"].inverse_transform([int(np.argmax(p_tire[0]))])[0],
        "gru_time_loss_sec": gru_time_loss,
        "stints": detailed,
    }

# %%
# Example inference files if missing
if not Path(RACE_CONTEXT_FILE).exists():
    pd.DataFrame([{
        "team_name": "Ferrari",
        "track_name": "Imola",
        "starting_position": 4,
        "starting_compound": "MEDIUM",
        "race_laps": 63
    }]).to_csv(RACE_CONTEXT_FILE, index=False)

if not Path(FORECAST_FILE).exists():
    pd.DataFrame([
        {"date":"2026-05-17T13:00:00Z","air_temperature":22.1,"track_temperature":37.5,"humidity":44,"rainfall":0.0,"wind_speed":2.9},
        {"date":"2026-05-17T13:10:00Z","air_temperature":22.4,"track_temperature":38.1,"humidity":43,"rainfall":0.0,"wind_speed":3.1},
        {"date":"2026-05-17T13:20:00Z","air_temperature":22.8,"track_temperature":38.9,"humidity":41,"rainfall":0.0,"wind_speed":2.7},
    ]).to_csv(FORECAST_FILE, index=False)

pre = joblib.load(PREPROC_FILE)
gru_model = keras.models.load_model(MODEL_FILE)
pit_loss_map = estimate_track_pit_loss_map()

rc = pd.read_csv(RACE_CONTEXT_FILE).iloc[0].to_dict()
fc = pd.read_csv(FORECAST_FILE)

rc["team_name"] = str(rc.get("team_name", "UNKNOWN_TEAM"))
rc["track_name"] = str(rc.get("track_name", "UNKNOWN_TRACK"))
rc["starting_position"] = float(rc.get("starting_position", 10))
rc["starting_compound"] = str(rc.get("starting_compound", "MEDIUM")).upper()
rc["race_laps"] = int(rc.get("race_laps", 60))

seq_input, ws = forecast_to_sequence_and_summary(fc, pre["weather_features"], pre["max_timesteps"])
wet = ws["rain_minutes_ratio"] > 0.2
cands = build_candidates(rc["starting_compound"], max_stops=3, wet=wet)
pit_loss = float(pit_loss_map.get(rc["track_name"], DEFAULT_PIT_LOSS))

results = [simulate_with_gru(gru_model, pre, rc, seq_input, ws, c, pit_loss) for c in cands]
res_df = pd.DataFrame([{k:v for k,v in r.items() if k != "stints"} for r in results]).sort_values("predicted_total_time_sec").reset_index(drop=True)
best = float(res_df.loc[0, "predicted_total_time_sec"])
res_df["delta_to_best_sec"] = res_df["predicted_total_time_sec"] - best

show = res_df.head(10).copy()
show["predicted_total_time"] = show["predicted_total_time_sec"].apply(format_time)
show["delta_to_best"] = show["delta_to_best_sec"].map(lambda x: f"+{x:.3f}s")

print("\n--- TOP 10 STRATEGIES ---\n")
display(show[["strategy", "stops", "predicted_total_time", "delta_to_best", "pit_loss_per_stop_sec"]])

best_strategy_name = res_df.loc[0, "strategy"]
best_obj = next(r for r in results if r["strategy"] == best_strategy_name)

print("=== RECOMMENDED STRATEGY ===")
print("Team:", rc["team_name"])
print("Track:", rc["track_name"])
print("Start pos:", rc["starting_position"])
print("Starting tire:", rc["starting_compound"])
print("Recommended sequence:", best_obj["strategy"])
print("Stops:", best_obj["stops"])
print("Predicted total time:", format_time(best_obj["predicted_total_time_sec"]))
print("Assumed pit loss per stop:", f"{best_obj['pit_loss_per_stop_sec']:.2f}s")

print("\nStint breakdown (best):")
for st in best_obj["stints"]:
    print(f"  Stint {st['stint']}: {st['compound']} | laps={st['laps']} | predicted={format_time(st['predicted_stint_time_sec'])}")
# Out:
# --- TOP 10 STRATEGIES ---
#                    strategy  stops predicted_total_time delta_to_best  \
# 0                    MEDIUM      0            99:01.333       +0.000s
# 1            MEDIUM -> SOFT      1            99:16.207      +14.874s
# 2            MEDIUM -> HARD      1            99:21.632      +20.299s
# 3    MEDIUM -> SOFT -> SOFT      2            99:46.335      +45.002s
# 4  MEDIUM -> SOFT -> MEDIUM      2            99:49.275      +47.942s
# 5  MEDIUM -> MEDIUM -> SOFT      2            99:49.275      +47.942s
# 6    MEDIUM -> SOFT -> HARD      2            99:51.795      +50.462s
# 7    MEDIUM -> HARD -> SOFT      2            99:51.795      +50.462s
# 8  MEDIUM -> MEDIUM -> HARD      2            99:54.735      +53.402s
# 9  MEDIUM -> HARD -> MEDIUM      2            99:54.735      +53.402s
#
#    pit_loss_per_stop_sec
# 0                 45.317
# 1                 45.317
# 2                 45.317
# 3                 45.317
# 4                 45.317
# 5                 45.317
# 6                 45.317
# 7                 45.317
# 8                 45.317
# 9                 45.317
# === RECOMMENDED STRATEGY ===
# Team: Ferrari
# Track: Imola
# Start pos: 4.0
# Starting tire: MEDIUM
# Recommended sequence: MEDIUM
# Stops: 0
# Predicted total time: 99:01.333
# Assumed pit loss per stop: 45.32s
#
# Stint breakdown (best):
#   Stint 1: MEDIUM | laps=63 | predicted=98:45.780
